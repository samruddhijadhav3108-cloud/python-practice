# %% [markdown]
# # ***`This is my first python program`***

# %%
print("hello world")
a=10
print(type(a))
hello=0.34
world='45'
word="b"
print(hello)
print(type(hello))
print(world)
print(type(world))
print(word)
print(type(word))

print(a+int(world))
# Out:
# hello world
# <class 'int'>
# 0.34
# <class 'float'>
# 45
# <class 'str'>
# b
# <class 'str'>
# 55

# %%
num1=122
num2=13
print("num1 is : ",num1)
print("num2 is :",num2)
#addition
print("addition is :",num1+num2)
#subtraction
print("subtraction is :",num1-num2)
#multiplication
print("multiplication is :",num1*num2)
#division
print("division is:",num1/num2)
#modulus
print("modulus is :", num1%num2)
# Out:
# num1 is :  122
# num2 is : 13
# addition is : 135
# subtraction is : 109
# multiplication is : 1586
# division is: 9.384615384615385
# modulus is : 5

# %%
var1 = 10000
print("Value of var1 is : ",var1)
print(f"Value of var1 is : {var1: .3f}")
# Out:
# Value of var1 is :  10000
# Value of var1 is :  10000.000

# %% [markdown]
# # ***Input Output Practice***

# %%
x=int(input("enter value for x"))
print("value of x is :",x, "and it's data type is :",type(x) )
# Out:
# enter value for x222
# value of x is : 222 and it's data type is : <class 'int'>

# %% [markdown]
# # ***Area Of Circle***

# %%
r=float(input("enter radius of circle "))
print("value of r is :",r)
aoc=3.14*r*r
print("area of circle is :",aoc)
# Out:
# enter radius of circle 6
# value of r is : 6.0
# area of circle is : 113.03999999999999

# %% [markdown]
# # ***Celsius To Fahrenheit***

# %%
c=int(input("enter temperature in celsius"))
print("value for c is:",c)
f=(9/5*c)+32
print("fahrenheit is:",f)
# Out:
# enter temperature in celsius34
# value for c is: 34
# fahrenheit is: 93.2

# %% [markdown]
# # ***Fahrenheit To Celsius***

# %%
f=float(input("enter temperature in fahrenheit"))
print("value for f is :",f)
c=5/9*(f-32)
print("celsius is :",c)
# Out:
# enter temperature in fahrenheit34
# value for f is : 34.0
# celsius is : 1.1111111111111112

# %% [markdown]
# # ***Area Of Square***

# %%
l=float(input("enter length of square"))
print("value of length is :",l)
aos=l*l
print("area of sqaure is:",aos)
# Out:
# enter length of square12
# value of length is : 12.0
# area of sqaure is: 144.0

# %% [markdown]
# # ***Area Of Rectangle***

# %%
l = float(input("enter value of length: "))
b = float(input("enter value of breadth: "))
print("value of length is:",l, "and breadth is:",b)
aor=l*b
print("area of rectangle is",aor)
# Out:
# enter value of length: 34
# enter value of breadth: 34
# value of length is: 34.0 and breadth is: 34.0
# area of rectangle is 1156.0

# %% [markdown]
# # ***Data Structures In Python***
#
#
#
# Lists
#
# Set
#
# Dictionary
#
# Tuples
#
# 1. Lists:
# Ordered, mutable collections of items.
# Can store heterogeneous data types.
# Defined using square brackets [].
# Example: my_list = [1, "hello", 3.14]
# 2. Tuples:
# Ordered, immutable collections of items.
# Similar to lists but cannot be modified after creation.
# Defined using parentheses ().
# Example: my_tuple = (1, "world", True)
# 3. Sets:
# Unordered collections of unique items.
# Do not allow duplicate elements.
# Defined using curly brackets {} or the set() constructor.
# Example: my_set = {1, 2, 3, 2} (will store only {1, 2, 3})
# 4. Dictionaries:
# Unordered collections of key-value pairs.
# Keys must be unique and immutable; values can be of any type.
# Defined using curly brackets {} with key-value pairs separated by colons.
# Example: my_dict = {"name": "Alice", "age": 30}

# %%
#list
my_list=[1, "hello", 3.14]
print("list is ",my_list)
#tuple
my_tuple=(1, 2, 3, 4)
print("tuple is ",my_tuple)
#set
my_set={1,2,3,4}
print("set is ",my_set)
#dictionary
my_dict={"name":"alice", "age":30}
print("dictionary is ", my_dict)
# Out:
# list is  [1, 'hello', 3.14]
# tuple is  (1, 2, 3, 4)
# set is  {1, 2, 3, 4}
# dictionary is  {'name': 'alice', 'age': 30}

# %% [markdown]
# # **Working With Lists**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Creating a Multi-Dimensional List
# (By Nesting a list inside a List)
list1=[1,2,3,4,True]
print(list1)
list2=[list1,[1,2,3,4]]
print(list2)
# Out:
# [1, 2, 3, 4, True]
# [[1, 2, 3, 4, True], [1, 2, 3, 4]]

# %%
# accessing a element from the
# list using index number
list_demo=[1,2,3,True,False,"FinTechYog"]
print(list_demo)
print(list_demo[2])
print(list_demo[-1])
print(list_demo[0])
list_demo[0]=True
print(list_demo[0])
# Out:
# [1, 2, 3, True, False, 'FinTechYog']
# 3
# FinTechYog
# 1
# True

# %% [markdown]
# ## ***Using list() Constructor***
#
# We can also create a list by passing an iterable (like a tuple, string or another list) to the list() function.

# %%
a1 = __builtins__.list((1,2,3,4))
print(a1)
b1 = __builtins__.list(("YOG"))
print(b1)
print(b1[0])
# Out:
# [1, 2, 3, 4]
# ['Y', 'O', 'G']
# Y

# %% [markdown]
# # ***Creating List with Repeated Elements***
#
# We can use the multiplication operator * to create a list with repeated items.

# %%
a2 = [3] * 5
print(a2)
print(a2[-1])
# Out:
# [3, 3, 3, 3, 3]
# 3

# %% [markdown]
# # ***Accessing List Elements***
#
# Elements in a list are accessed using indexing. Python indexes start at 0, so a[0] gives the first element. Negative indexes allow access from the end (e.g., -1 gives the last element).

# %%
a3 = [10, 20, 30, 40, 50, True, False]
print(a3[0])
print(a3[-1])
print(a3[3:7])
# Out:
# 10
# False
# [40, 50, True, False]

# %% [markdown]
# # ***Adding Elements into List***
#
# We can add elements to a list using the following methods:
#
# append(): Adds an element at the end of the list.
#
# extend(): Adds multiple elements to the end of the list.
#
# insert(): Adds an element at a specific position.
#
# clear(): removes all items.

# %%
a4 = []

a4.append(10)
print("After append(10):", a4)

a4.insert(0,5)
print("After insert(0,5):",a4)

a4.extend([15,20,25])
print("After extend({15,20,25}):", a4)

a4.clear()
print("After clear():",a4)
# Out:
# After append(10): [10]
# After insert(0,5): [5, 10]
# After extend({15,20,25}): [5, 10, 15, 20, 25]
# After clear(): []

# %% [markdown]
# # ***Updating Elements into List***
#
# Since lists are mutable, we can update elements by accessing them via their index.

# %%
a5 = [11, 12, 13, 14]
a5[1]=25
print(a5)
# Out:
# [11, 25, 13, 14]

# %% [markdown]
# # ***Removing Elements from List***
#
# We can remove elements from a list using:
#
#
# remove(): Removes the first occurrence of an element.
#
# pop(): Removes the element at a specific index or the last element if no index is specified.
#
# del statement: Deletes an element at a specified index.

# %%
a6 = [21, 22, 23, 24, 25]

a6.remove(23)
print("after remove(23):",a6)

popped_val = a6.pop(1)
print("popped element:", popped_val)
print("after pop(1):",a6)

del a6[0]
print("after del a6[0]:",a6)
# Out:
# after remove(23): [21, 22, 24, 25]
# popped element: 22
# after pop(1): [21, 24, 25]
# after del a6[0]: [24, 25]

# %% [markdown]
# # ***Iterating Over Lists***
#
# We can iterate over lists using loops, which is useful for performing actions on each item.

# %%
a.clear()
print(a)
a = ['apple', 'banana', 'cherry']
print(a)

for item in a:
  print(item)
# Out:
# []
# ['apple', 'banana', 'cherry']
# apple
# banana
# cherry

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***Nested Lists***
#
# A nested list is a list within another list, which is useful for representing matrices or tables. We can access nested elements by chaining indexes.

# %%
matrix = [ [1,2,3],
           [4,5,6],
           [7,8,9] ]
print(matrix[1][2])
# Out:
# 6

# %% [markdown]
# # ***List Comprehension***
#
# List comprehension is a concise way to create lists using a single line of code. It is useful for applying an operation or filter to items in an iterable, such as a list or range.

# %%
squares = [x**2 for x in range(1,6)]
print(squares)
print(sum(squares))
# Out:
# [1, 4, 9, 16, 25]
# 55

# %% [markdown]
# # ***Explanation:***
#
# for x in range(1, 6): loops through each number from 1 to 5 (excluding 6).
# x**2: squares each number x.
# [ ]: collects all the squared numbers into a new list.

# %%
squares = [x**2 for x in range(1,6)]
max(squares)
# Out:
# 25

# %% [markdown]
#  **Tuples**

# %% [markdown]
# A tuple in Python is an immutable ordered collection of elements.
#
# Tuples are similar to lists, but unlike lists, they cannot be changed after their creation (i.e., they are immutable).
# Tuples can hold elements of different data types.
# The main characteristics of tuples are being ordered, heterogeneous and immutable.

# %% [markdown]
# # ***Creating a Tuple***
#
# A tuple is created by placing all the items inside parentheses (), separated by commas. A tuple can have any number of items and they can be of different data types.

# %%
t1 = ()
print(t1)
#USING STRING
t1 = ('FinTechYog', 'Mumbai')
print(t1)
#using list
li = [1,2,3,4,5]
print(tuple(li))
#using built-in function
t1 = tuple('FinTechYog')
print(t1)
# Out:
# ()
# ('FinTechYog', 'Mumbai')
# (1, 2, 3, 4, 5)
# ('F', 'i', 'n', 'T', 'e', 'c', 'h', 'Y', 'o', 'g')

# %% [markdown]
# https://www.geeksforgeeks.org/python/python-tuples/
