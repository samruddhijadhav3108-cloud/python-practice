# %%
import pandas as pd
data1 = pd.read_csv("STD.csv")
print(data1)
# Out:
#   Name  Marks
# 0    A     46
# 1    B     12
# 2    C     10
# 3    D     42
# 4    E     46
# 5    F     38
# 6    G     20
# 7    H     39
# 8    I     18
# 9    J     31

# %%
data2 = pd.read_excel("demo.xlsx")
print(max(data2.maths))
# Out:
# 67

# %%
with open('test2.txt', 'r') as file:
    lines = file.readlines()
    for line in lines:
        # .strip() removes the newline character (\n)
        print(line.strip())
# Out:
# test1.txt
