# %%
# !pip install pandas
#pip command is use to install packages

# %%
import pandas as pd

data = {
    "calories": [420.23, 380.33, 390.56, 550, 450, 670, 300, 239],
    "duration": [50, 40, 45, 35, 30, 25, 20, 10]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
#head function use to print first five rows data
print(df.head())
#tail function use to print last five rows data
print(df.tail())
# Out:
#    calories  duration
# 0    420.23        50
# 1    380.33        40
# 2    390.56        45
# 3    550.00        35
# 4    450.00        30
#    calories  duration
# 3     550.0        35
# 4     450.0        30
# 5     670.0        25
# 6     300.0        20
# 7     239.0        10

# %%
df.calories.abs()
df.calories.count()
# Out:
# np.int64(8)
