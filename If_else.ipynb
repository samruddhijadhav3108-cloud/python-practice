# %% [markdown]
# # **The If Statement**

# %% [markdown]
# An if statement is used as a form of conditional programming; something you
# probably do every day in the real world. That is, you need to decide whether you
# are going to have tea or coffee or to decide if you will have toast or a muffin for
# breakfast etc. In each of these cases you are making a choice, usually based on
# some information such as I had coffee yesterday, so I will have tea today.
# In Python such choices are represented programmatically by the if condition
# statement.
# In this construct if some condition is true some action is performed, optionally if
# it is not true some other action may be performed instead.

# %% [markdown]
# if स्टेटमेंट हे कंडिशनल प्रोग्रामिंगच्या स्वरूपात वापरले जाते; जे तुम्ही वास्तविक जगात दररोज करत असाल. म्हणजेच, तुम्हाला चहा घ्यायचा की कॉफी घ्यायची हे ठरवावे लागेल किंवा नाश्त्यासाठी टोस्ट घ्यायचा की मफिन घ्यायचा हे ठरवावे लागेल. या प्रत्येक प्रकरणात तुम्ही निवड करत आहात, सहसा
# काही माहितीवर आधारित जसे की मी काल कॉफी घेतली, म्हणून मी आज चहा घेईन.
#
# पायथॉनमध्ये अशा निवडी if कंडिशन
# स्टेटमेंटद्वारे प्रोग्रामेटिकली दर्शविल्या जातात.
#
# या रचनामध्ये जर काही कंडिशन खरे असेल तर काही क्रिया केली जाते, पर्यायी जर ते खरे नसेल तर त्याऐवजी काही दुसरी क्रिया केली जाऊ शकते.

# %% [markdown]
# Working with an If Statement
# In its most basic from, the if statement is
# if <condition-evaluating-to-boolean>:
# statement
# Note that the condition must evaluate to True or False (or an equivalent
# value—see later in this chapter). If the condition is True then we will execute the
# indented statement.
# Note that indentation, this is very important in Python; indeed, layout of the code
# is very, very important in Python. Indentation is used to determine how one piece of
# code should be associated with another piece of the code.
# Let us look at a simple example,

# %% [markdown]
# If स्टेटमेंटसह काम करणे
# त्याच्या सर्वात मूलभूत स्वरूपात, if स्टेटमेंट आहे
# if <condition-evaluating-to-boolean>:
# statement
# लक्षात घ्या की कंडिशनचे मूल्यांकन खरे किंवा खोटे (किंवा समतुल्य
# मूल्य—या प्रकरणात नंतर पहा) केले पाहिजे. जर कंडिशन खरे असेल तर आपण
# इंडेंटेड स्टेटमेंट कार्यान्वित करू.
# लक्षात घ्या की इंडेंटेशन, हे पायथॉनमध्ये खूप महत्वाचे आहे; खरंच, पायथॉनमध्ये कोडचा लेआउट
# खूप, खूप महत्वाचा आहे. कोडचा एक तुकडा कोडच्या दुसऱ्या तुकड्याशी कसा जोडला जावा हे निर्धारित करण्यासाठी इंडेंटेशन वापरले जाते.
# आपण एक साधे उदाहरण पाहूया,

# %%
num = int(input("enter number : "))
if num > 0 :
  print(num, " is positive")
else:
  print(num, " is negative")
# Out:
# enter number : -3
# -3  is negative

# %% [markdown]
# In this example, the user has input a number; if it is less than zero a message
# noting this will be printed to the user. If the number is positive; then nothing will be
# output.
# For example,
# Enter a number: -1
# -1 is negative

# %% [markdown]
# या उदाहरणात, वापरकर्त्याने एक संख्या प्रविष्ट केली आहे; जर ती शून्यापेक्षा कमी असेल तर एक संदेश
# हे वापरकर्त्याला प्रिंट केले जाईल असे नमूद केले जाईल. जर संख्या सकारात्मक असेल; तर काहीही आउटपुट होणार नाही.
# उदाहरणार्थ,
# एक संख्या प्रविष्ट करा: -1
# -1 ऋण आहे

# %% [markdown]
# If we wish to execute multiple statements when our condition is True we can
# indent several lines; in fact all lines indented to the same level after the if
# statement will automatically be part of the if statement. For example:

# %% [markdown]
# जर आपल्याला आपली स्थिती सत्य असताना अनेक स्टेटमेंट्स कार्यान्वित करायची असतील तर आपण अनेक ओळी इंडेंट करू शकतो; खरं तर if
# स्टेटमेंट नंतर समान पातळीवर इंडेंट केलेल्या सर्व ओळी आपोआप if स्टेटमेंटचा भाग होतील. उदाहरणार्थ:

# %%
num = float(input("Enter Number: "))
if num >= 0 :
  print(num, " is positive")
  print(num, " squared is" ,num*num)

print("bye")
# Out:
# Enter Number: -4
# bye

# %% [markdown]
# However, if we enter the value −1 then we get
# Enter another number: -1
# Bye
# Note that neither of the indented lines was executed.
# This is because the two indented lines are associated with the if statement and
# will only be executed if the Boolean condition evaluates (returns) True. However,
# the statement print('Bye') is not part of the if statement; it is merely the next
# statement to executed after the if statement (and its associated print() statements) have finished.

# %% [markdown]
# तथापि, जर आपण −1 व्हॅल्यू एंटर केली तर आपल्याला
# दुसरा नंबर एंटर करा: -1
# बाय
# लक्षात घ्या की इंडेंट केलेल्या कोणत्याही ओळी कार्यान्वित झाल्या नाहीत.
# कारण दोन इंडेंट केलेल्या ओळी if स्टेटमेंटशी संबंधित आहेत आणि
# जर बुलियन कंडिशनने True चे मूल्यांकन केले (परत) केले तरच त्या कार्यान्वित होतील. तथापि,
# प्रिंट('बाय') हे स्टेटमेंट if स्टेटमेंटचा भाग नाही; ते if स्टेटमेंट (आणि त्याच्याशी संबंधित प्रिंट() स्टेटमेंट) पूर्ण झाल्यानंतर कार्यान्वित होणारे पुढील
# स्टेटमेंट आहे.

# %% [markdown]
# # **Else in an If Statement**
# We can also define an else part of an if statement; this is an optional element that
# can be run if the conditional part of the if statement returns False. For example:

# %% [markdown]
# आपण if स्टेटमेंटचा इतर भाग देखील परिभाषित करू शकतो; हा एक पर्यायी घटक आहे जो if स्टेटमेंटचा सशर्त भाग False परत केल्यास चालवता येतो. उदाहरणार्थ:

# %%
num = int(input("enter the number:"))
if num < 0 :
  print(num, " is negative")
else:
  print(num, " is positive")
# Out:
# enter the number:-1
# -1  is negative

# %% [markdown]
# Now when this code is executed, if the number entered is less than zero then the
# first print() statement will be run otherwise (else) the second print() statement will be run. However, we are guaranteed that at least one (and at most one) of
# the print() statements will execute.
# For example, in run 1 if we enter the value 1:
# Enter yet another number: 1
# Its not negative
# And in run 2 if we enter the value −1:
# Enter yet another number: -1
# Its negative

# %% [markdown]
# आता जेव्हा हा कोड कार्यान्वित केला जातो, जर प्रविष्ट केलेली संख्या शून्यापेक्षा कमी असेल तर
# पहिले प्रिंट() स्टेटमेंट रन केले जाईल अन्यथा (अन्यथा) दुसरे प्रिंट() स्टेटमेंट रन केले जाईल. तथापि, आम्हाला हमी आहे की प्रिंट() स्टेटमेंटपैकी किमान एक (आणि जास्तीत जास्त एक) कार्यान्वित होईल.
# उदाहरणार्थ, रन १ मध्ये जर आपण व्हॅल्यू १ एंटर केली तर:
# आणखी एक नंबर एंटर करा: १
# ती ऋण नाही
# आणि रन २ मध्ये जर आपण व्हॅल्यू −१ एंटर केली तर:
# आणखी एक नंबर एंटर करा: -१
# ती ऋण आहे

# %% [markdown]
# # **The Use of elif**
# In some cases there may be several conditions you want to test, with each condition
# being tested if the previous one failed. This else-if scenario is supported in Python
# by the elif element of an if statement.
# 68 6 Flow of Control Using If Statements
# The elif element of an if statement follows the if part and comes before any
# (optional) else part. It has the format:
# elif <condition-evaluating-to-boolean>:
# statement
# For example:

# %% [markdown]
# काही प्रकरणांमध्ये तुम्हाला अनेक अटी तपासायच्या असू शकतात, जर मागील अट अयशस्वी झाली तर प्रत्येक स्थितीची चाचणी घेतली जाईल. हा else-if परिस्थिती Python मध्ये if स्टेटमेंटच्या elif घटकाद्वारे समर्थित आहे.
#
# 68 6 If स्टेटमेंट्स वापरून नियंत्रणाचा प्रवाह
# if स्टेटमेंटचा elif घटक if भागाचे अनुसरण करतो आणि कोणत्याही
# (पर्यायी) else भागाच्या आधी येतो. त्याचे स्वरूप आहे:
# elif <condition-evaluating-to-boolean>:
# statement
# उदाहरणार्थ:

# %%
marks = int(input("enter marks:"))
if marks <0 or marks >100:
  print("Invalid Marks")
elif marks < 40 :
  print("Fail")
elif marks < 50 :
  print("Grade-C")
elif marks < 60 :
  print("Grade-B")
elif marks < 80 :
  print("Grade-A")
else:
  print("Grade-O")
# Out:
# enter marks:88
# Grade-O

# %% [markdown]
# Here we can see that the first if condition failed (as savings is not equal to 0).
# However, the next elif also must have returned False as savings were greater
# than 500. In fact it was the second elif statement that returned True and thus the
# associated print('Thats a tidy sum') statement was executed. Having
# executed this statement the if statement then terminated (the remaining elif and
# else parts were ignored).

# %% [markdown]
# येथे आपण पाहू शकतो की पहिली if कंडिशन अयशस्वी झाली (कारण बचत 0 च्या बरोबरीची नाही).
# तथापि, पुढील elif देखील False परत आले असावे कारण बचत 500 पेक्षा जास्त होती. खरं तर, दुसरे elif स्टेटमेंट होते ज्याने True परत केले आणि अशा प्रकारे
# संबंधित प्रिंट ('Thats a tidy sum') स्टेटमेंट कार्यान्वित झाले. हे स्टेटमेंट कार्यान्वित केल्यानंतर if स्टेटमेंट नंतर समाप्त झाले (उर्वरित elif आणि
# else भाग दुर्लक्षित केले गेले).

# %% [markdown]
# # **Nesting If Statements**
# It is possible to nest one if statement inside another. This term nesting indicates
# that one if statement is located within part of the another if statement and can be
# used to refine the conditional behaviour of the program.
# An example is given below. Note that it allows some behaviour to be performed
# before and after the nested if statement is executed/run. Also note that indentation is
# key here as it is how Python works out whether the if statements are nested or not.

# %% [markdown]
# एका इफ स्टेटमेंटला दुसऱ्या इफ स्टेटमेंटमध्ये नेस्ट करणे शक्य आहे. नेस्टिंग हा शब्द दर्शवितो की एक इफ स्टेटमेंट दुसऱ्या इफ स्टेटमेंटच्या काही भागात स्थित आहे आणि प्रोग्रामच्या कंडिशनल वर्तनाला सुधारण्यासाठी वापरला जाऊ शकतो.
# खाली एक उदाहरण दिले आहे. लक्षात ठेवा की ते नेस्टेड इफ स्टेटमेंट कार्यान्वित/चालवण्यापूर्वी आणि नंतर काही वर्तन करण्यास अनुमती देते. हे देखील लक्षात ठेवा की येथे इंडेंटेशन महत्वाचे आहे कारण पायथॉन इफ स्टेटमेंट नेस्टेड आहेत की नाही हे कसे ठरवते.

# %%
snowing = True
temp = -1
if temp < 0:
  print("It is freezing")
  if snowing:
    print("Put on boots")
  print("Time for Hot Chocolate")
print("Bye")
# Out:
# It is freezing
# Put on boots
# Time for Hot Chocolate
# Bye

# %% [markdown]
# In this example, if the temperature if less than Zero then we will enter the if
# block of code. If it is not less than zero we will skip the whole if statement and
# jump to the print('Bye') statement which is after both If statements.
# In this case the temperature is set to −1 and so we will enter the If statement. We
# will then print out the 'It is freezing' string. At this point another if statement is
# nested within the first if statement. A check will now be made to see if it is
# snowing. Notice that snowing is already a Boolean value and so will be either
# True or False and illustrates that a Boolean value on its own can be used here.
# As it is snowing, we will print out 'Put on boots'.
# However, the statement printing out 'Time for Hot Chocolate' is not part of the
# nested if. It is part of the outer if (this is where indentation is important). If you
# wanted it to only be printed out if it was snowing then it must be indented to the
# same level as the first statement in the nested if block, for example:

# %% [markdown]
# या उदाहरणात, जर तापमान शून्यापेक्षा कमी असेल तर आपण कोडचा if
# ब्लॉक प्रविष्ट करू. जर ते शून्यापेक्षा कमी नसेल तर आपण संपूर्ण if स्टेटमेंट वगळू आणि print('Bye') स्टेटमेंटवर जाऊ जे दोन्ही If स्टेटमेंट नंतर आहे.
#
# या प्रकरणात तापमान −1 वर सेट केले आहे आणि म्हणून आपण If स्टेटमेंट प्रविष्ट करू. आपण नंतर 'It is freezing' स्ट्रिंग प्रिंट करू. या टप्प्यावर दुसरे if स्टेटमेंट पहिल्या if स्टेटमेंटमध्ये नेस्ट केले आहे. आता ते
# स्नोइंग आहे की नाही हे तपासले जाईल. लक्षात घ्या की स्नोइंग हे आधीच बुलियन व्हॅल्यू आहे आणि म्हणून ते
# ट्रू किंवा फॉल्स असेल आणि हे स्पष्ट करते की येथे स्वतःहून बुलियन व्हॅल्यू वापरली जाऊ शकते.
#
# हिमवर्षाव होत असताना, आपण 'पुट ऑन बूट' प्रिंट करू.
#
# तथापि, 'टाइम फॉर हॉट चॉकलेट' प्रिंट करणारे स्टेटमेंट
# नेस्टेड if चा भाग नाही. ते बाह्य if चा भाग आहे (येथे इंडेंटेशन महत्वाचे आहे). जर तुम्हाला ते फक्त बर्फ पडत असेल तरच प्रिंट करायचे असेल तर ते नेस्टेड इफ ब्लॉकमधील पहिल्या स्टेटमेंटप्रमाणेच इंडेंट केले पाहिजे, उदाहरणार्थ:

# %%
snowing = True
temp = -1
if temp < 0:
  print("It is freezing")
  if snowing:
    print("Put on boots")
  print("Time for Hot Chocolate")
print("Bye")
# Out:
# It is freezing
# Put on boots
# Time for Hot Chocolate
# Bye

# %% [markdown]
# This now changes the inner (or nested) if to have two print statements
# associated with it.
# This may seem subtle, but it is key to how Python uses layout to link together
# individual statements.

# %% [markdown]
# जर दोन प्रिंट स्टेटमेंट्सशी संबंधित असतील तर हे आता आतील (किंवा नेस्टेड) ​​बदलते.
# हे सूक्ष्म वाटू शकते, परंतु पायथॉन वैयक्तिक स्टेटमेंट्स एकत्र जोडण्यासाठी लेआउट कसे वापरते हे महत्त्वाचे आहे.

# %% [markdown]
# # **If Expressions**
# An if expression is a short hand form of an if statement that returns a value. In
# fact, the difference between an expression and a statement in a programming language is just that; expressions return a value; statements do not.
# 70 6 Flow of Control Using If Statements
# It is quite common to want to assign a specific value to a variable dependent on
# some condition. For example, if we wish to decide if someone is a teenager or not
# then we might check to see if they are over 12 and under 20. We could write this as:

# %% [markdown]
# if अभिव्यक्ती ही if विधानाची एक लघुरूप आहे जी मूल्य परत करते.
# खरं तर, प्रोग्रामिंग भाषेतील अभिव्यक्ती आणि विधान यांच्यातील फरक फक्त एवढाच आहे; अभिव्यक्ती मूल्य परत करतात; विधाने देत नाहीत.
#
# ७० ६ If विधानांचा वापर करून नियंत्रणाचा प्रवाह
#
# काही परिस्थितीनुसार एखाद्या चलाला विशिष्ट मूल्य नियुक्त करण्याची इच्छा असणे सामान्य आहे. उदाहरणार्थ, जर आपल्याला एखादी व्यक्ती किशोरवयीन आहे की नाही हे ठरवायचे असेल तर आपण ते १२ वर्षांपेक्षा जास्त आणि २० वर्षांपेक्षा कमी वयाचे आहे का ते तपासू शकतो. आपण हे असे लिहू शकतो:

# %%
age = 15
status = None
if (age > 12) and age < 20:
 status = 'teenager'
else:
 status = 'not teenager'
print(status)
# Out:
# teenager

# %% [markdown]
# However, this is quite long and it may not be obvious that the real intent of this
# code was to assign an appropriate value to status.
# An alternative is an if expression. The format of an if expression is
# <result1> if <condition-is-met> else <result2>
# That is the result returned from the if expression is the first value unless the
# condition fails in which case the result returned will be the value after the else. It
# may seem confusing at first, but it becomes easier when you see an example.
# For example, using the if expression we can perform a test to determine the value
# to assign to status and return it as the result of the if expression. For example:

# %% [markdown]
# तथापि, हे बरेच लांब आहे आणि या
# कोडचा खरा हेतू स्थितीला योग्य मूल्य देणे हा होता हे स्पष्ट होऊ शकत नाही.
# एक पर्याय म्हणजे if अभिव्यक्ती. if अभिव्यक्तीचे स्वरूप
# <result1> if <condition-is-met> else <result2>
#
# ते म्हणजे if अभिव्यक्तीमधून परत येणारा निकाल हा पहिला मूल्य आहे जोपर्यंत
# अट अयशस्वी होत नाही अशा परिस्थितीत परत येणारा निकाल else नंतरचा मूल्य असेल.
# सुरुवातीला ते गोंधळात टाकणारे वाटू शकते, परंतु जेव्हा तुम्ही उदाहरण पाहता तेव्हा ते सोपे होते.
# उदाहरणार्थ, if अभिव्यक्ती वापरून आपण स्थितीला नियुक्त करण्यासाठी मूल्य निश्चित करण्यासाठी आणि if अभिव्यक्तीच्या परिणाम म्हणून ते परत करण्यासाठी चाचणी करू शकतो. उदाहरणार्थ:

# %%
status = ('teenager' if age > 12 and age < 20 else 'not teenager')
print(status)
# Out:
# teenager

# %% [markdown]
# However now the code is much more
# concise, and it is clear that the purpose of the test is to determine the result to assign
# to status.

# %% [markdown]
# तथापि, आता कोड खूपच संक्षिप्त आहे आणि हे स्पष्ट आहे की चाचणीचा उद्देश स्थितीला नेमून देण्यासाठी निकाल निश्चित करणे आहे.

# %% [markdown]
# # **A Note on True and False**
# Python is actually quite flexible when it comes to what actually is used to represent
#
# True and False, in fact the following rules apply
#
# • 0, '' (empty strings), None equate to False
#
# • Non zero, non empty strings, any object equate to True.
#
# However, we would recommend sticking to just True and False as it is often
# a cleaner and safer approach.

# %% [markdown]
# # **खरे आणि खोटे यावर एक टीप**
#
# प्रत्यक्षात काय दर्शवायचे याचा विचार केला तर पायथॉन प्रत्यक्षात बरेच लवचिक आहे
#
# खरे आणि खोटे, खरं तर खालील नियम लागू होतात
#
# • ०, '' (रिक्त स्ट्रिंग), काहीही खोटे नाही
#
# • शून्य नाही, रिक्त नाही स्ट्रिंग, कोणताही ऑब्जेक्ट खरे आहे.
#
# तथापि, आम्ही फक्त खरे आणि खोटेच चिकटून राहण्याची शिफारस करतो कारण ते बहुतेकदा
# एक स्वच्छ आणि सुरक्षित दृष्टिकोन असतो.
